# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/sara-kassani/GoogleColab/blob/master/GoogleColab_ZIP_GZ.ipynb)

# %%
# !apt-get -y install sox
# !apt-get -y install csh
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   libasound2 libasound2-data libflac8 libgsm1 libltdl7 libmagic-mgc libmagic1
#   libogg0 libopencore-amrnb0 libopencore-amrwb0 libsndfile1 libsox-fmt-alsa
#   libsox-fmt-base libsox2 libvorbis0a libvorbisenc2 libvorbisfile3 libwavpack1
# Suggested packages:
#   libasound2-plugins alsa-utils file libsox-fmt-all
# The following NEW packages will be installed:
#   libasound2 libasound2-data libflac8 libgsm1 libltdl7 libmagic-mgc libmagic1
#   libogg0 libopencore-amrnb0 libopencore-amrwb0 libsndfile1 libsox-fmt-alsa
#   libsox-fmt-base libsox2 libvorbis0a libvorbisenc2 libvorbisfile3 libwavpack1
#   sox
# 0 upgraded, 19 newly installed, 0 to remove and 0 not upgraded.
# Need to get 1,860 kB of archives.
# After this operation, 11.6 MB of additional disk space will be used.
# ...

# %%
# !wget "https://drive.google.com/open?id=1LT_VNUocO__7sg_VVUSLJm_P5PzrXVQz"
# Out:
# --2018-08-16 23:27:45--  https://drive.google.com/open?id=1LT_VNUocO__7sg_VVUSLJm_P5PzrXVQz
# Resolving drive.google.com (drive.google.com)... 172.217.193.139, 172.217.193.102, 172.217.193.100, ...
# Connecting to drive.google.com (drive.google.com)|172.217.193.139|:443... connected.
# HTTP request sent, awaiting response... 307 OK
# Location: https://drive.google.com/file/d/1LT_VNUocO__7sg_VVUSLJm_P5PzrXVQz/view?usp=drive_open [following]
# --2018-08-16 23:27:46--  https://drive.google.com/file/d/1LT_VNUocO__7sg_VVUSLJm_P5PzrXVQz/view?usp=drive_open
# Reusing existing connection to drive.google.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘open?id=1LT_VNUocO__7sg_VVUSLJm_P5PzrXVQz.1’
#
# open?id=1LT_VNUocO_     [ <=>                ] 124.70K  --.-KB/s    in 0.009s
#
# 2018-08-16 23:27:46 (13.4 MB/s) - ‘open?id=1LT_VNUocO__7sg_VVUSLJm_P5PzrXVQz.1’ saved [127695]

# %%
# !pip install wget
# Out:
# ...
# done
#   Stored in directory: /content/.cache/pip/wheels/40/15/30/7d8f7cea2902b4db79e3fea550d7d7b85ecb27ef992b618f3f
# Successfully built wget
# ...

# %%
import os
print(os.listdir("./"))
# Out:
# ['.config', 'sample_data', 'datalab', 'upload-iciar.tar.gz', 'data', 'data.zip', '.ipython', 'gdrive', 'adc.json', '.local', 'open', 'upload-iciar', '.keras', 'open?id=1LT_VNUocO__7sg_VVUSLJm_P5PzrXVQz.1', '.forever', 'ImageDataGenerator', 'drive', '.gdfuse', 'data2.zip', 'open?id=1LT_VNUocO__7sg_VVUSLJm_P5PzrXVQz', '.cache', 'patches.zip', '.wget-hsts']

# %%
import requests

def download_file_from_google_drive(id, destination):
    URL = "https://docs.google.com/uc?export=download"

    session = requests.Session()

    response = session.get(URL, params = { 'id' : id }, stream = True)
    token = get_confirm_token(response)

    if token:
        params = { 'id' : id, 'confirm' : token }
        response = session.get(URL, params = params, stream = True)

    save_response_content(response, destination)    

def get_confirm_token(response):
    for key, value in response.cookies.items():
        if key.startswith('download_warning'):
            return value

    return None

def save_response_content(response, destination):
    CHUNK_SIZE = 32768

    with open(destination, "wb") as f:
        for chunk in response.iter_content(CHUNK_SIZE):
            if chunk: # filter out keep-alive new chunks
                f.write(chunk)

# %%
# https://drive.google.com/open?id=1pHq3zRhZsvENUnyngc07WLvxi6YumBci


file_id = '1pHq3zRhZsvENUnyngc07WLvxi6YumBci'
destination = 'upload-iciar.tar.gz'
download_file_from_google_drive(file_id, destination)

# %%
ls
# Out:
# adc.json   ImageDataGenerator/
# data/      open
# data2.zip  open?id=1LT_VNUocO__7sg_VVUSLJm_P5PzrXVQz
# datalab@   open?id=1LT_VNUocO__7sg_VVUSLJm_P5PzrXVQz.1
# data.zip   patches.zip
# drive/     sample_data/
# gdrive/    upload-iciar.tar.gz

# %%
# !tar xfvz upload-iciar.tar.gz
# Out:
# upload-iciar/
# upload-iciar/pretrained-models/
# upload-iciar/pretrained-models/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# upload-iciar/2.Xception-With.ipynb
# upload-iciar/4.VGGNet2-With.ipynb
# upload-iciar/1.ResNet-With.ipynb
# upload-iciar/Reinhard/
# upload-iciar/Reinhard/Invasive/
# upload-iciar/Reinhard/Invasive/iv012_patch013.png
# upload-iciar/Reinhard/Invasive/iv079_patch031.png
# upload-iciar/Reinhard/Invasive/iv083_patch002.png
# upload-iciar/Reinhard/Invasive/iv010_patch022.png
# upload-iciar/Reinhard/Invasive/iv025_patch004.png
# upload-iciar/Reinhard/Invasive/iv100_patch011.png
# upload-iciar/Reinhard/Invasive/iv084_patch034.png
# upload-iciar/Reinhard/Invasive/iv014_patch014.png
# upload-iciar/Reinhard/Invasive/iv011_patch034.png
# upload-iciar/Reinhard/Invasive/iv050_patch029.png
# upload-iciar/Reinhard/Invasive/iv041_patch029.png
# upload-iciar/Reinhard/Invasive/iv057_patch016.png
# upload-iciar/Reinhard/Invasive/iv080_patch011.png
# ...

# %%
ls
# Out:
# adc.json             open
# data/                open?id=1LT_VNUocO__7sg_VVUSLJm_P5PzrXVQz
# data2.zip            open?id=1LT_VNUocO__7sg_VVUSLJm_P5PzrXVQz.1
# datalab@             patches.zip
# data.zip             sample_data/
# drive/               upload-iciar/
# gdrive/              upload-iciar.tar.gz
# ImageDataGenerator/

# %%
# %cd
# Out:
# /content

# %%
ls
# Out:
# adc.json             open
# data/                open?id=1LT_VNUocO__7sg_VVUSLJm_P5PzrXVQz
# data2.zip            open?id=1LT_VNUocO__7sg_VVUSLJm_P5PzrXVQz.1
# datalab@             patches.zip
# data.zip             sample_data/
# drive/               upload-iciar/
# gdrive/              upload-iciar.tar.gz
# ImageDataGenerator/
